# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
imf_data = pd.read_csv('../data/imf-who-covid-19-vaccine-supply-tracker.csv',skiprows=2, skipfooter=4)
df_imf = pd.DataFrame(imf_data)
df_imf.head()
# Out:
# C:\Users\alex0\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#   Countries and areas ISO3  Population  \
# 0              Canada  CAN  37,742,157
# 1               Italy  ITA  60,461,828
# 2         New Zealand  NZL   4,822,233
# 3           Australia  AUS  25,499,881
# 4             Hungary  HUN   9,660,350
#
#    Secured Vaccine, Before Adjustment (millions of courses)   \
# 0                                                175
# 1                                                207
# 2                                                 16
# 3                                                 83
# 4                                                 31
#
#    Adjustment (millions of courses)   Secured Vaccine (millions of courses)   \
# ...

# %%
df_imf = df_imf.rename(columns={"ISO3": "iso_code"})
df_imf.head(1)
# Out:
#   Countries and areas iso_code  Population  \
# 0              Canada      CAN  37,742,157
#
#    Secured Vaccine, Before Adjustment (millions of courses)   \
# 0                                                175
#
#    Adjustment (millions of courses)   Secured Vaccine (millions of courses)   \
# 0                                -19                                     156
#
#    Vaccine Needed to Reach 60% of Population (millions of courses)   \
# 0                                               -
#
#    Bilateral Deals (millions of courses)   Donations (millions of courses)   \
# 0                                     174                                 1
#
#    COVAX donations (millions of courses)   ...  Adjustment (% of population)   \
# 0                                    -     ...                            -49
#
#    Secured Vaccine (% of population)   \
# 0                                 414
#
#    Vaccine Needed to Reach 60% of Population (% of population)   \
# ...

# %%
df_imf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 25 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Countries and areas                                                193 non-null    object
#  1   iso_code                                                           193 non-null    object
#  2   Population                                                         193 non-null    object
#  3    Secured Vaccine, Before Adjustment (millions of courses)          193 non-null    object
#  4    Adjustment (millions of courses)                                  193 non-null    object
#  5    Secured Vaccine (millions of courses)                             193 non-null    object
#  6    Vaccine Needed to Reach 60% of Population (millions of courses)   193 non-null    object
# ...

# %%
df_imf['Population'].replace(',','', regex=True, inplace = True)

# %%
df_imf['Population']
# Out:
# 0      37742157
# 1      60461828
# 2       4822233
# 3      25499881
# 4       9660350
#          ...
# 188      548927
# 189       59194
# 190    40222503
# 191     1402985
# 192     2540916
# Name: Population, Length: 193, dtype: object

# %%
# c = df_imf.select_dtypes(object).columns
df_imf['Population'] = df_imf['Population'].apply(pd.to_numeric,errors='coerce')

# %%
df_imf['Population']
# Out:
# 0      37742157
# 1      60461828
# 2       4822233
# 3      25499881
# 4       9660350
#          ...
# 188      548927
# 189       59194
# 190    40222503
# 191     1402985
# 192     2540916
# Name: Population, Length: 193, dtype: int64
